# %% [markdown]
# <a href="https://colab.research.google.com/github/harisa-elvawany-siallagan/ProjectPrakPPh/blob/main/ProjectUAS_PPh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    pass


# Analisis Kolom dan Informasi Dasar
# Cek apakah dataframe berhasil dimuat sebelum melanjutkan
if 'df_aset_tetap' in locals() and 'df_kebijakan_fiskal' in locals() and 'df_transaksi_keuangan' in locals():
    print("\n" + "="*30)
    print("--- Analisis Aset Tetap ---")
    print("="*30)
    # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_aset_tetap.head()) # Menggunakan display untuk tampilan yang lebih baik di Colab/Jupyter
    print("\nInformasi Kolom:")
    print(df_aset_tetap.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_aset_tetap.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_aset_tetap.isnull().sum()) # Menampilkan jumlah nilai yang hilang

    print("\n" + "="*30)
    print("--- Analisis Kebijakan Fiskal ---")
    print("="*30)
    # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_kebijakan_fiskal.head()) # Menggunakan display
    print("\nInformasi Kolom:")
    print(df_kebijakan_fiskal.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_kebijakan_fiskal.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_kebijakan_fiskal.isnull().sum()) # Menampilkan jumlah nilai yang hilang


    print("\n" + "="*30)
    print("--- Analisis Transaksi Keuangan ---")
    print("="*30)
     # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_transaksi_keuangan.head()) # Menggunakan display
    print("\nInformasi Kolom:")
    print(df_transaksi_keuangan.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_transaksi_keuangan.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_transaksi_keuangan.isnull().sum()) # Menampilkan jumlah nilai yang hilang


    # Visualisasi Data (bagian ini sama seperti sebelumnya, hanya untuk konteks lengkap)
    print("\n" + "="*30)
    print("--- Visualisasi Data ---")
    print("="*30)

    # Visualisasi untuk Aset Tetap (Histogram untuk kolom numerik)
    # Ganti 'Nama_Kolom_Numerik_Aset' dengan nama kolom numerik yang relevan di df_aset_tetap Anda
    nama_kolom_numerik_aset = 'Nama_Kolom_Numerik_Aset' # <--- GANTI NAMA KOLOM INI
    if nama_kolom_numerik_aset in df_aset_tetap.columns and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_numerik_aset]):
        plt.figure(figsize=(10, 6))
        sns.histplot(data=df_aset_tetap, x=nama_kolom_numerik_aset, bins=20, kde=True, color='dodgerblue')
        plt.title(f'Distribusi {nama_kolom_numerik_aset} Aset Tetap', fontsize=14)
        plt.xlabel(nama_kolom_numerik_aset, fontsize=12)
        plt.ylabel('Frekuensi', fontsize=12)
        plt.grid(axis='y', alpha=0.75)
        plt.show()
    else:
        print(f"\nKolom '{nama_kolom_numerik_aset}' tidak ditemukan atau bukan numerik di df_aset_tetap. Lewati visualisasi histogram.")


    # Contoh visualisasi untuk Kebijakan Fiskal (Bar Plot)
    # Ganti 'NamaKolomKategoriAnda' dan 'NamaKolomNilaiAnda' dengan nama kolom yang relevan
    nama_kolom_kategori_fiskal = 'NamaKolomKategoriAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_fiskal = 'NamaKolomNilaiAnda'       # <--- GANTI NAMA KOLOM INI
    try:
        if nama_kolom_kategori_fiskal in df_kebijakan_fiskal.columns and nama_kolom_nilai_fiskal in df_kebijakan_fiskal.columns:
            plt.figure(figsize=(12, 7))
            sns.barplot(data=df_kebijakan_fiskal, x=nama_kolom_kategori_fiskal, y=nama_kolom_nilai_fiskal, palette='viridis')
            plt.title(f'Perbandingan {nama_kolom_nilai_fiskal} per {nama_kolom_kategori_fiskal} Kebijakan Fiskal', fontsize=14)
            plt.xlabel(nama_kolom_kategori_fiskal, fontsize=12)
            plt.ylabel(nama_kolom_nilai_fiskal, fontsize=12)
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.show()
        else:
             print(f"\nSalah satu kolom ('{nama_kolom_kategori_fiskal}' atau '{nama_kolom_nilai_fiskal}') tidak ditemukan di df_kebijakan_fiskal. Lewati visualisasi bar plot.")
    except Exception as e:
         print(f"\nError saat visualisasi bar plot df_kebijakan_fiskal: {e}")


    # Contoh visualisasi untuk Transaksi Keuangan (Line Plot untuk tren waktu)
    # Ganti 'NamaKolomTanggalAnda' dan 'NamaKolomNilaiAnda' dengan nama kolom yang relevan
    nama_kolom_tanggal_keuangan = 'NamaKolomTanggalAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_keuangan = 'NamaKolomNilaiAnda'     # <--- GANTI NAMA KOLOM INI
    try:
        if nama_kolom_tanggal_keuangan in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan in df_transaksi_keuangan.columns:
            df_transaksi_keuangan[nama_kolom_tanggal_keuangan] = pd.to_datetime(df_transaksi_keuangan[nama_kolom_tanggal_keuangan], errors='coerce')
            df_transaksi_keuangan.dropna(subset=[nama_kolom_tanggal_keuangan], inplace=True)
            df_transaksi_keuangan = df_transaksi_keuangan.sort_values(by=nama_kolom_tanggal_keuangan)

            plt.figure(figsize=(12, 7))
            sns.lineplot(data=df_transaksi_keuangan, x=nama_kolom_tanggal_keuangan, y=nama_kolom_nilai_keuangan, color='indianred')
            plt.title(f'Tren {nama_kolom_nilai_keuangan} Transaksi Keuangan dari Waktu ke Waktu', fontsize=14)
            plt.xlabel('Tanggal', fontsize=12)
            plt.ylabel(nama_kolom_nilai_keuangan, fontsize=12)
            plt.tight_layout()
            plt.show()
        else:
            print(f"\nSalah satu kolom ('{nama_kolom_tanggal_keuangan}' atau '{nama_kolom_nilai_keuangan}') tidak ditemukan di df_transaksi_keuangan. Lewati visualisasi line plot.")
    except Exception as e:
         print(f"\nError saat visualisasi line plot df_transaksi_keuangan: {e}")


    # Analisis Komprehensif (Contoh)
    print("\n" + "="*30)
    print("--- Analisis Komprehensif ---")
    print("="*30)

    # Contoh: Korelasi antar kolom numerik di Aset Tetap
    numeric_cols_aset = df_aset_tetap.select_dtypes(include=['number']).columns
    if len(numeric_cols_aset) > 1:
        print("\nMatriks Korelasi Aset Tetap:")
        print(df_aset_tetap[numeric_cols_aset].corr())

        plt.figure(figsize=(8, 6))
        sns.heatmap(df_aset_tetap[numeric_cols_aset].corr(), annot=True, cmap='coolwarm', fmt=".2f")
        plt.title('Matriks Korelasi Aset Tetap', fontsize=14)
        plt.show()
    else:
        print("\nTidak cukup kolom numerik di Aset Tetap untuk menghitung korelasi.")

    # Contoh: Agregasi data per kategori di Kebijakan Fiskal
    nama_kolom_kategori_fiskal_agg = 'NamaKolomKategoriAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_fiskal_agg = 'NamaKolomNilaiAnda'       # <--- GANTI NAMA KOLOM INI
    print("\nAgregasi Nilai per Kategori di Kebijakan Fiskal:")
    try:
        if nama_kolom_kategori_fiskal_agg in df_kebijakan_fiskal.columns and nama_kolom_nilai_fiskal_agg in df_kebijakan_fiskal.columns:
            agregasi_kebijakan = df_kebijakan_fiskal.groupby(nama_kolom_kategori_fiskal_agg)[nama_kolom_nilai_fiskal_agg].sum().reset_index()
            print(agregasi_kebijakan)
            plt.figure(figsize=(10, 6))
            sns.barplot(data=agregasi_kebijakan, x=nama_kolom_kategori_fiskal_agg, y=nama_kolom_nilai_fiskal_agg, palette='tab10')
            plt.title('Total Nilai per Kategori Kebijakan Fiskal', fontsize=14)
            plt.xlabel(nama_kolom_kategori_fiskal_agg, fontsize=12)
            plt.ylabel(f'Total {nama_kolom_nilai_fiskal_agg}', fontsize=12)
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.show()
        else:
            print(f"Salah satu kolom ('{nama_kolom_kategori_fiskal_agg}' atau '{nama_kolom_nilai_fiskal_agg}') tidak ditemukan untuk agregasi di df_kebijakan_fiskal.")
    except Exception as e:
         print(f"Error saat agregasi df_kebijakan_fiskal: {e}")


    # Contoh: Analisis deret waktu pada Transaksi Keuangan (jika ada kolom tanggal)
    nama_kolom_tanggal_keuangan_ts = 'NamaKolomTanggalAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_keuangan_ts = 'NamaKolomNilaiAnda'     # <--- GANTI NAMA KOLOM INI
    try:
        if nama_kolom_tanggal_keuangan_ts in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan_ts in df_transaksi_keuangan.columns:
            df_transaksi_keuangan[nama_kolom_tanggal_keuangan_ts] = pd.to_datetime(df_transaksi_keuangan[nama_kolom_tanggal_keuangan_ts], errors='coerce')
            df_transaksi_keuangan.dropna(subset=[nama_kolom_tanggal_keuangan_ts], inplace=True)
            df_transaksi_keuangan_ts = df_transaksi_keuangan.set_index(nama_kolom_tanggal_keuangan_ts)

            print(f"\nResampling Bulanan {nama_kolom_nilai_keuangan_ts} Transaksi Keuangan (Total Bulanan):")
            resampled_data = df_transaksi_keuangan_ts[nama_kolom_nilai_keuangan_ts].resample('M').sum()
            print(resampled_data.head())

            plt.figure(figsize=(12, 7))
            resampled_data.plot(kind='line', marker='o', linestyle='-', color='teal')
            plt.title(f'Tren {nama_kolom_nilai_keuangan_ts} Transaksi Keuangan (Bulanan)', fontsize=14)
            plt.xlabel('Bulan', fontsize=12)
            plt.ylabel(f'Total {nama_kolom_nilai_keuangan_ts}', fontsize=12)
            plt.grid(True)
            plt.tight_layout()
            plt.show()

        else:
            print(f"Salah satu kolom ('{nama_kolom_tanggal_keuangan_ts}' atau '{nama_kolom_nilai_keuangan_ts}') tidak ditemukan untuk analisis deret waktu di df_transaksi_keuangan.")
    except Exception as e:
         print(f"Error saat analisis deret waktu df_transaksi_keuangan: {e}")


    print("\n" + "="*30)
    print("Analisis selesai.")
    print("="*30)
else:
    print("\n--- Analisis dan Visualisasi Dilewati Karena Gagal Memuat File ---")
# Out:
# Mounted at /content/drive
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# --- Analisis dan Visualisasi Dilewati Karena Gagal Memuat File ---

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    pass


# Analisis Kolom dan Informasi Dasar
# Cek apakah dataframe berhasil dimuat sebelum melanjutkan
if 'df_aset_tetap' in locals() and 'df_kebijakan_fiskal' in locals() and 'df_transaksi_keuangan' in locals():
    print("\n" + "="*30)
    print("--- Analisis Aset Tetap ---")
    print("="*30)
    # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_aset_tetap.head()) # Menggunakan display untuk tampilan yang lebih baik di Colab/Jupyter
    print("\nInformasi Kolom:")
    print(df_aset_tetap.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_aset_tetap.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_aset_tetap.isnull().sum()) # Menampilkan jumlah nilai yang hilang

    print("\n" + "="*30)
    print("--- Analisis Kebijakan Fiskal ---")
    print("="*30)
    # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_kebijakan_fiskal.head()) # Menggunakan display
    print("\nInformasi Kolom:")
    print(df_kebijakan_fiskal.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_kebijakan_fiskal.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_kebijakan_fiskal.isnull().sum()) # Menampilkan jumlah nilai yang hilang


    print("\n" + "="*30)
    print("--- Analisis Transaksi Keuangan ---")
    print("="*30)
     # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_transaksi_keuangan.head()) # Menggunakan display
    print("\nInformasi Kolom:")
    print(df_transaksi_keuangan.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_transaksi_keuangan.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_transaksi_keuangan.isnull().sum()) # Menampilkan jumlah nilai yang hilang


    # Visualisasi Data
    print("\n" + "="*30)
    print("--- Visualisasi Data ---")
    print("="*30)

    # Visualisasi untuk Aset Tetap (Histogram untuk kolom numerik)
    # Ganti 'Nama_Kolom_Numerik_Aset' dengan nama kolom numerik yang relevan di df_aset_tetap Anda
    # Contoh: Jika ada kolom 'Nilai_Aset' atau 'Jumlah_Unit'
    nama_kolom_numerik_aset = 'Nama_Kolom_Numerik_Aset' # <--- GANTI NAMA KOLOM INI
    if nama_kolom_numerik_aset in df_aset_tetap.columns and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_numerik_aset]):
        plt.figure(figsize=(10, 6))
        # Menggunakan warna 'skyblue' atau 'dodgerblue' atau palet lainnya
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    pass


# Analisis Kolom dan Informasi Dasar
# Cek apakah dataframe berhasil dimuat sebelum melanjutkan
if 'df_aset_tetap' in locals() and 'df_kebijakan_fiskal' in locals() and 'df_transaksi_keuangan' in locals():
    print("\n" + "="*30)
    print("--- Analisis Aset Tetap ---")
    print("="*30)
    # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_aset_tetap.head()) # Menggunakan display untuk tampilan yang lebih baik di Colab/Jupyter
    print("\nInformasi Kolom:")
    print(df_aset_tetap.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_aset_tetap.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_aset_tetap.isnull().sum()) # Menampilkan jumlah nilai yang hilang

    print("\n" + "="*30)
    print("--- Analisis Kebijakan Fiskal ---")
    print("="*30)
    # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_kebijakan_fiskal.head()) # Menggunakan display
    print("\nInformasi Kolom:")
    print(df_kebijakan_fiskal.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_kebijakan_fiskal.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_kebijakan_fiskal.isnull().sum()) # Menampilkan jumlah nilai yang hilang


    print("\n" + "="*30)
    print("--- Analisis Transaksi Keuangan ---")
    print("="*30)
     # Menampilkan beberapa baris pertama data
    print("\nBeberapa baris pertama:")
    display(df_transaksi_keuangan.head()) # Menggunakan display
    print("\nInformasi Kolom:")
    print(df_transaksi_keuangan.info()) # Menampilkan informasi kolom dan tipe data
    print("\nDeskripsi Statistik:")
    print(df_transaksi_keuangan.describe()) # Menampilkan statistik deskriptif
    print("\nNilai yang hilang per kolom:")
    print(df_transaksi_keuangan.isnull().sum()) # Menampilkan jumlah nilai yang hilang


    # Visualisasi Data
    print("\n" + "="*30)
    print("--- Visualisasi Data ---")
    print("="*30)

    # Visualisasi untuk Aset Tetap (Histogram untuk kolom numerik)
    # Ganti 'Nama_Kolom_Numerik_Aset' dengan nama kolom numerik yang relevan di df_aset_tetap Anda
    # Contoh: Jika ada kolom 'Nilai_Aset' atau 'Jumlah_Unit'
    nama_kolom_numerik_aset = 'Nama_Kolom_Numerik_Aset' # <--- GANTI NAMA KOLOM INI
    if nama_kolom_numerik_aset in df_aset_tetap.columns and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_numerik_aset]):
        plt.figure(figsize=(10, 6))
        # Menggunakan warna 'skyblue' atau 'dodgerblue' atau palet lainnya
        sns.histplot(data=df_aset_tetap, x=nama_kolom_numerik_aset, bins=20, kde=True, color='dodgerblue')
        plt.title(f'Distribusi {nama_kolom_numerik_aset} Aset Tetap', fontsize=14)
        plt.xlabel(nama_kolom_numerik_aset) # Fix: Added closing parenthesis
        plt.ylabel('Frekuensi')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()
    else:
        print(f"\nKolom '{nama_kolom_numerik_aset}' tidak ditemukan atau bukan tipe numerik di df_aset_tetap.")

    # Visualisasi untuk Kebijakan Fiskal (Contoh: Line plot jika ada kolom 'Tahun' dan 'Anggaran')
    # Ganti 'Nama_Kolom_Tahun' dan 'Nama_Kolom_Anggaran' sesuai nama kolom di df_kebijakan_fiskal Anda
    nama_kolom_tahun = 'Nama_Kolom_Tahun' # <--- GANTI NAMA KOLOM INI
    nama_kolom_anggaran = 'Nama_Kolom_Anggaran' # <--- GANTI NAMA KOLOM INI
    if nama_kolom_tahun in df_kebijakan_fiskal.columns and nama_kolom_anggaran in df_kebijakan_fiskal.columns:
        # Pastikan kolom tahun bisa diurutkan
        try:
            df_kebijakan_fiskal_sorted = df_kebijakan_fiskal.sort_values(by=nama_kolom_tahun)
            plt.figure(figsize=(12, 7))
            # Menggunakan marker 'o' dan linestyle '-'
            sns.lineplot(data=df_kebijakan_fiskal_sorted, x=nama_kolom_tahun, y=nama_kolom_anggaran, marker='o', linestyle='-', color='indianred')
            plt.title(f'Tren {nama_kolom_anggaran} terhadap {nama_kolom_tahun}', fontsize=14)
            plt.xlabel(nama_kolom_tahun)
            plt.ylabel(nama_kolom_anggaran)
            plt.grid(True, linestyle='--', alpha=0.6)
            plt.xticks(rotation=45) # Memutar label x agar tidak bertumpuk
            plt.tight_layout() # Menyesuaikan layout agar tidak terpotong
            plt.show()
        except Exception as e:
            print(f"\nError saat membuat line plot untuk kebijakan fiskal: {e}")
            print(f"Pastikan kolom '{nama_kolom_tahun}' dan '{nama_kolom_anggaran}' ada dan datanya sesuai.")
    else:
         print(f"\nKolom '{nama_kolom_tahun}' atau '{nama_kolom_anggaran}' tidak ditemukan di df_kebijakan_fiskal.")

    # Visualisasi untuk Transaksi Keuangan (Contoh: Bar plot untuk 'Jenis_Transaksi' vs 'Jumlah')
    # Ganti 'Nama_Kolom_Jenis_Transaksi' dan 'Nama_Kolom_Jumlah' sesuai nama kolom di df_transaksi_keuangan Anda
    nama_kolom_jenis_transaksi = 'Nama_Kolom_Jenis_Transaksi' # <--- GANTI NAMA KOLOM INI
    nama_kolom_jumlah = 'Nama_Kolom_Jumlah' # <--- GANTI NAMA KOLOM INI
    if nama_kolom_jenis_transaksi in df_transaksi_keuangan.columns and nama_kolom_jumlah in df_transaksi_keuangan.columns:
         # Menggunakan palet warna seaborn
        plt.figure(figsize=(10, 6))
        sns.barplot(data=df_transaksi_keuangan, x=nama_kolom_jenis_transaksi, y=nama_kolom_jumlah, palette='viridis')
        plt.title(f'Jumlah Transaksi berdasarkan {nama_kolom_jenis_transaksi}', fontsize=14)
        plt.xlabel(nama_kolom_jenis_transaksi)
        plt.ylabel(nama_kolom_jumlah)
        plt.xticks(rotation=45, ha='right') # Memutar label x
        plt.tight_layout()
        plt.grid(axis='y', linestyle='--', alpha=0.6) # Hanya grid di sumbu y
        plt.show()
    else:
        print(f"\nKolom '{nama_kolom_jenis_transaksi}' atau '{nama_kolom_jumlah}' tidak ditemukan di df_transaksi_keuangan.")

    print("\nAnalisis dan visualisasi dasar selesai.")

else:
    print("\nDataFrames tidak berhasil dimuat. Analisis tidak dapat dilanjutkan.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# DataFrames tidak berhasil dimuat. Analisis tidak dapat dilanjutkan.

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    pass


# Analisis Mendalam Per Kolom
# Cek apakah dataframe berhasil dimuat sebelum melanjutkan
if 'df_aset_tetap' in locals() and 'df_kebijakan_fiskal' in locals() and 'df_transaksi_keuangan' in locals():

    # --- Analisis Mendalam Aset Tetap ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Aset Tetap ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_aset_tetap.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_aset_tetap.describe())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_aset_tetap.isnull().sum())

    print("\nAnalisis Kolom Individu:")
    for col in df_aset_tetap.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_aset_tetap[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_aset_tetap[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_aset_tetap[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_aset_tetap[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (median, skew, kurtosis)
            print(df_aset_tetap[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot)
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_aset_tetap, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_aset_tetap, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_aset_tetap[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_aset_tetap[col].min()}")
                 print(f"Tanggal Terakhir: {df_aset_tetap[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_aset_tetap[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_aset_tetap[col].nunique() <= 20: # Batas arbitrer, bisa disesuaikan
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_aset_tetap, y=col, order=df_aset_tetap[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.tight_layout()
                 plt.show()
            elif df_aset_tetap[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_aset_tetap[col].nunique()}) untuk visualisasi count plot.")


    # --- Analisis Mendalam Kebijakan Fiskal ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Kebijakan Fiskal ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_kebijakan_fiskal.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_kebijakan_fiskal.describe())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_kebijakan_fiskal.isnull().sum())

    print("\nAnalisis Kolom Individu:")
    for col in df_kebijakan_fiskal.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_kebijakan_fiskal[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_kebijakan_fiskal[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_kebijakan_fiskal[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_kebijakan_fiskal[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (median, skew, kurtosis)
            print(df_kebijakan_fiskal[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot)
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_kebijakan_fiskal, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_kebijakan_fiskal, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_kebijakan_fiskal[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_kebijakan_fiskal[col].min()}")
                 print(f"Tanggal Terakhir: {df_kebijakan_fiskal[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_kebijakan_fiskal[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_kebijakan_fiskal[col].nunique() <= 20: # Batas arbitrer, bisa disesuaikan
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_kebijakan_fiskal, y=col, order=df_kebijakan_fiskal[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.tight_layout()
                 plt.show()
            elif df_kebijakan_fiskal[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_kebijakan_fiskal[col].nunique()}) untuk visualisasi count plot.")


    # --- Analisis Mendalam Transaksi Keuangan ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Transaksi Keuangan ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_transaksi_keuangan.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_transaksi_keuangan.describe())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_transaksi_keuangan.isnull().sum())

    print("\nAnalisis Kolom Individu:")
    for col in df_transaksi_keuangan.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_transaksi_keuangan[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_transaksi_keuangan[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_transaksi_keuangan[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_transaksi_keuangan[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (median, skew, kurtosis)
            print(df_transaksi_keuangan[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot)
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_transaksi_keuangan, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_transaksi_keuangan, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_transaksi_keuangan[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_transaksi_keuangan[col].min()}")
                 print(f"Tanggal Terakhir: {df_transaksi_keuangan[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")


        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_transaksi_keuangan[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_transaksi_keuangan[col].nunique() <= 20: # Batas arbitrer, bisa disesuaikan
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_transaksi_keuangan, y=col, order=df_transaksi_keuangan[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.tight_layout()
                 plt.show()
            elif df_transaksi_keuangan[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_transaksi_keuangan[col].nunique()}) untuk visualisasi count plot.")


    print("\n" + "="*40)
    print("Analisis mendalam selesai.")
    print("="*40)

else:
    print("\n--- Analisis Mendalam Dilewati Karena Gagal Memuat File ---")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# --- Analisis Mendalam Dilewati Karena Gagal Memuat File ---

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
    dataframes_loaded = True
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    dataframes_loaded = False
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    dataframes_loaded = False
    pass


# Analisis Dasar (Tabelar + Grafik Struktur Dasar)
if dataframes_loaded: # Hanya lakukan analisis jika dataframe berhasil dimuat

    # Fungsi helper untuk melakukan analisis dasar dan visualisasi struktur untuk satu dataframe
    def analyze_dataframe_structure(df, df_name):
        print("\n" + "="*30)
        print(f"--- Analisis Dasar: {df_name} ---")
        print("="*30)

        # Menampilkan beberapa baris pertama data (Tabelar)
        print(f"\nBeberapa baris pertama {df_name}:")
        display(df.head()) # Menggunakan display untuk tampilan yang lebih baik di Colab/Jupyter

        # Informasi Kolom (Tabelar)
        print(f"\nInformasi Kolom {df_name}:")
        df.info() # df.info() akan langsung mencetak outputnya

        # Statistik Deskriptif (Tabelar)
        print(f"\nDeskripsi Statistik {df_name}:")
        print(df.describe().to_string()) # Menggunakan to_string() agar semua kolom deskriptif terlihat

        # Nilai yang hilang per kolom (Tabelar)
        print(f"\nJumlah Nilai yang hilang per kolom {df_name}:")
        print(df.isnull().sum().to_string())


        # --- Visualisasi Struktur Dasar (Grafik) ---
        print(f"\n--- Visualisasi Struktur Dasar: {df_name} ---")

        # Grafik 1: Jumlah Nilai Non-Null per Kolom
        non_null_counts = df.count()
        plt.figure(figsize=(10, 6))
        sns.barplot(x=non_null_counts.index, y=non_null_counts.values, palette='viridis')
        plt.title(f'Jumlah Nilai Non-Null per Kolom ({df_name})', fontsize=14)
        plt.xlabel('Kolom', fontsize=12)
        plt.ylabel('Jumlah Nilai Non-Null', fontsize=12)
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

        # Grafik 2: Jumlah Nilai yang Hilang per Kolom
        missing_counts = df.isnull().sum()
        # Filter kolom yang memiliki nilai hilang > 0
        missing_counts = missing_counts[missing_counts > 0]
        if not missing_counts.empty:
            plt.figure(figsize=(10, 6))
            sns.barplot(x=missing_counts.index, y=missing_counts.values, palette='magma')
            plt.title(f'Jumlah Nilai yang Hilang per Kolom ({df_name})', fontsize=14)
            plt.xlabel('Kolom', fontsize=12)
            plt.ylabel('Jumlah Nilai Hilang', fontsize=12)
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.show()
        else:
            print(f"Tidak ada nilai yang hilang di {df_name} untuk divisualisasikan.")


        # Grafik 3: Persentase Tipe Data
        dtype_counts = df.dtypes.value_counts()
        if not dtype_counts.empty:
            plt.figure(figsize=(8, 8))
            # Menggunakan .astype(str) karena tipe data itu sendiri bisa kompleks (misal: dtype('int64'))
            dtype_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
            plt.title(f'Distribusi Tipe Data ({df_name})', fontsize=14)
            plt.ylabel('') # Hapus label y default untuk pie chart
            plt.axis('equal') # Pastikan pie chart berbentuk lingkaran
            plt.show()
        else:
             print(f"Tidak dapat menentukan tipe data di {df_name} untuk visualisasi pie chart.")


    # Lakukan analisis struktur dasar untuk setiap dataframe
    analyze_dataframe_structure(df_aset_tetap, "df_aset_tetap")
    analyze_dataframe_structure(df_kebijakan_fiskal, "df_kebijakan_fiskal")
    analyze_dataframe_structure(df_transaksi_keuangan, "df_transaksi_keuangan")

else:
    print("\n--- Analisis Dasar Dilewati Karena Gagal Memuat File ---")

# Bagian Visualisasi Data (Tetap sama seperti sebelumnya untuk hubungan/tren)
# ... (kode visualisasi lanjutan seperti histogram, bar plot, line plot, dll. ada di sini)
# Anda bisa menyalin bagian visualisasi dari jawaban sebelumnya dan meletakkannya di bawah ini jika Anda ingin menjalankannya juga.

# Analisis Komprehensif (Tetap sama seperti sebelumnya)
# ... (kode analisis komprehensif seperti korelasi, agregasi, deret waktu ada di sini)
# Anda bisa menyalin bagian analisis komprehensif dari jawaban sebelumnya dan meletakkannya di bawah ini jika Anda ingin menjalankannya juga.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# --- Analisis Dasar Dilewati Karena Gagal Memuat File ---

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
    dataframes_loaded = True
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    dataframes_loaded = False
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    dataframes_loaded = False
    pass


# Analisis Mendalam Per Kolom (Termasuk Visualisasi Berwarna)
if dataframes_loaded: # Hanya lakukan analisis jika dataframe berhasil dimuat

    # --- Analisis Mendalam Aset Tetap ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Aset Tetap ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_aset_tetap.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    # Menggunakan to_string() agar semua baris describe terlihat
    print(df_aset_tetap.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_aset_tetap.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_aset_tetap.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_aset_tetap[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_aset_tetap[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_aset_tetap[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_aset_tetap[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_aset_tetap[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1) # 1 baris, 2 kolom, plot ke-1
            sns.histplot(data=df_aset_tetap, x=col, kde=True, color='skyblue') # Warna Histogram
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2) # 1 baris, 2 kolom, plot ke-2
            sns.boxplot(data=df_aset_tetap, x=col, color='lightcoral') # Warna Box Plot
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)


            plt.tight_layout() # Menyesuaikan layout agar tidak tumpang tindih
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_aset_tetap[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_aset_tetap[col].min()}")
                 print(f"Tanggal Terakhir: {df_aset_tetap[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_aset_tetap[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_aset_tetap[col].nunique() <= 20: # Batas arbitrer untuk visualisasi count plot
                 plt.figure(figsize=(10, 6))
                 # Menggunakan palette untuk warna batang yang berbeda
                 sns.countplot(data=df_aset_tetap, y=col, order=df_aset_tetap[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_aset_tetap[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_aset_tetap[col].nunique()}) untuk visualisasi count plot.")


    # --- Analisis Mendalam Kebijakan Fiskal ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Kebijakan Fiskal ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_kebijakan_fiskal.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_kebijakan_fiskal.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_kebijakan_fiskal.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_kebijakan_fiskal.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_kebijakan_fiskal[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_kebijakan_fiskal[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_kebijakan_fiskal[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_kebijakan_fiskal[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_kebijakan_fiskal[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_kebijakan_fiskal, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_kebijakan_fiskal, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_kebijakan_fiskal[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_kebijakan_fiskal[col].min()}")
                 print(f"Tanggal Terakhir: {df_kebijakan_fiskal[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_kebijakan_fiskal[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_kebijakan_fiskal[col].nunique() <= 20: # Batas arbitrer
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_kebijakan_fiskal, y=col, order=df_kebijakan_fiskal[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_kebijakan_fiskal[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_kebijakan_fiskal[col].nunique()}) untuk visualisasi count plot.")


    # --- Analisis Mendalam Transaksi Keuangan ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Transaksi Keuangan ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_transaksi_keuangan.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_transaksi_keuangan.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_transaksi_keuangan.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_transaksi_keuangan.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_transaksi_keuangan[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_transaksi_keuangan[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_transaksi_keuangan[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_transaksi_keuangan[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_transaksi_keuangan[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_transaksi_keuangan, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_transaksi_keuangan, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_transaksi_keuangan[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_transaksi_keuangan[col].min()}")
                 print(f"Tanggal Terakhir: {df_transaksi_keuangan[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_transaksi_keuangan[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_transaksi_keuangan[col].nunique() <= 20: # Batas arbitrer
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_transaksi_keuangan, y=col, order=df_transaksi_keuangan[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_transaksi_keuangan[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_transaksi_keuangan[col].nunique()}) untuk visualisasi count plot.")

    # Visualisasi Hubungan/Tren Lanjutan (dari jawaban sebelumnya)
    print("\n" + "="*40)
    print("--- Visualisasi Hubungan dan Tren ---")
    print("="*40)

    # Contoh: Korelasi antar kolom numerik di Aset Tetap
    numeric_cols_aset = df_aset_tetap.select_dtypes(include=['number']).columns
    if len(numeric_cols_aset) > 1:
        print("\nMatriks Korelasi Aset Tetap:")
        # Visualisasi Korelasi (Heatmap) - Berwarna
        plt.figure(figsize=(8, 6))
        sns.heatmap(df_aset_tetap[numeric_cols_aset].corr(), annot=True, cmap='coolwarm', fmt=".2f")
        plt.title('Matriks Korelasi Aset Tetap', fontsize=14)
        plt.show()
    else:
        print("\nTidak cukup kolom numerik di Aset Tetap untuk menghitung korelasi.")

    # Visualisasi untuk Kebijakan Fiskal (Bar Plot)
    # Ganti 'NamaKolomKategoriAnda' dan 'NamaKolomNilaiAnda' dengan nama kolom yang relevan
    nama_kolom_kategori_fiskal = 'NamaKolomKategoriAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_fiskal = 'NamaKolomNilaiAnda'       # <--- GANTI NAMA KOLOM INI
    try:
        if nama_kolom_kategori_fiskal in df_kebijakan_fiskal.columns and nama_kolom_nilai_fiskal in df_kebijakan_fiskal.columns:
            plt.figure(figsize=(12, 7))
            sns.barplot(data=df_kebijakan_fiskal, x=nama_kolom_kategori_fiskal, y=nama_kolom_nilai_fiskal, palette='viridis')
            plt.title(f'Perbandingan {nama_kolom_nilai_fiskal} per {nama_kolom_kategori_fiskal} Kebijakan Fiskal', fontsize=14)
            plt.xlabel(nama_kolom_kategori_fiskal, fontsize=12)
            plt.ylabel(nama_kolom_nilai_fiskal, fontsize=12)
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.show()
        else:
             print(f"\nSalah satu kolom ('{nama_kolom_kategori_fiskal}' atau '{nama_kolom_nilai_fiskal}') tidak ditemukan di df_kebijakan_fiskal. Lewati visualisasi bar plot.")
    except Exception as e:
         print(f"\nError saat visualisasi bar plot df_kebijakan_fiskal: {e}")


    # Visualisasi untuk Transaksi Keuangan (Line Plot untuk tren waktu)
    # Ganti 'NamaKolomTanggalAnda' dan 'NamaKolomNilaiAnda' dengan nama kolom yang relevan
    nama_kolom_tanggal_keuangan = 'NamaKolomTanggalAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_keuangan = 'NamaKolomNilaiAnda'     # <--- GANTI NAMA KOLOM INI
    try:
        if nama_kolom_tanggal_keuangan in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan in df_transaksi_keuangan.columns:
            df_transaksi_keuangan[nama_kolom_tanggal_keuangan] = pd.to_datetime(df_transaksi_keuangan[nama_kolom_tanggal_keuangan], errors='coerce')
            df_transaksi_keuangan.dropna(subset=[nama_kolom_tanggal_keuangan], inplace=True)
            df_transaksi_keuangan = df_transaksi_keuangan.sort_values(by=nama_kolom_tanggal_keuangan)

            plt.figure(figsize=(12, 7))
            sns.lineplot(data=df_transaksi_keuangan, x=nama_kolom_tanggal_keuangan, y=nama_kolom_nilai_keuangan, color='indianred')
            plt.title(f'Tren {nama_kolom_nilai_keuangan} Transaksi Keuangan dari Waktu ke Waktu', fontsize=14)
            plt.xlabel('Tanggal', fontsize=12)
            plt.ylabel(nama_kolom_nilai_keuangan, fontsize=12)
            plt.tight_layout()
            plt.show()
        else:
            print(f"\nSalah satu kolom ('{nama_kolom_tanggal_keuangan}' atau '{nama_kolom_nilai_keuangan}') tidak ditemukan di df_transaksi_keuangan. Lewati visualisasi line plot.")
    except Exception as e:
         print(f"\nError saat visualisasi line plot df_transaksi_keuangan: {e}")


    print("\n" + "="*40)
    print("Analisis mendalam dan visualisasi selesai.")
    print("="*40)


else:
    print("\n--- Analisis Mendalam dan Visualisasi Dilewati Karena Gagal Memuat File ---")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# --- Analisis Mendalam dan Visualisasi Dilewati Karena Gagal Memuat File ---

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
    dataframes_loaded = True
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    dataframes_loaded = False
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    dataframes_loaded = False
    pass


# Analisis Kolom dan Informasi Dasar (Tetap ada untuk konteks, meskipun fokus pada visualisasi)
if dataframes_loaded:
    print("\n" + "="*30)
    print("--- Analisis Aset Tetap ---")
    print("="*30)
    display(df_aset_tetap.head())
    print(df_aset_tetap.info())
    print(df_aset_tetap.describe().to_string())
    print(df_aset_tetap.isnull().sum().to_string())

    print("\n" + "="*30)
    print("--- Analisis Kebijakan Fiskal ---")
    print("="*30)
    display(df_kebijakan_fiskal.head())
    print(df_kebijakan_fiskal.info())
    print(df_kebijakan_fiskal.describe().to_string())
    print(df_kebijakan_fiskal.isnull().sum().to_string())

    print("\n" + "="*30)
    print("--- Analisis Transaksi Keuangan ---")
    print("="*30)
    display(df_transaksi_keuangan.head())
    print(df_transaksi_keuangan.info())
    print(df_transaksi_keuangan.describe().to_string())
    print(df_transaksi_keuangan.isnull().sum().to_string())


    # Visualisasi Data untuk Relasi dan Tren (Grafik Berwarna)
    print("\n" + "="*30)
    print("--- Visualisasi Relasi dan Tren Data ---")
    print("="*30)

    # Visualisasi untuk Aset Tetap (Contoh: Scatter Plot jika ada 2 kolom numerik untuk melihat relasi)
    # Ganti 'NamaKolomNumerik1' dan 'NamaKolomNumerik2' dengan nama kolom numerik yang ingin Anda lihat relasinya
    nama_kolom_num1_aset = 'NamaKolomNumerik1' # <--- GANTI NAMA KOLOM INI (misal: 'Jumlah', 'Nilai')
    nama_kolom_num2_aset = 'NamaKolomNumerik2' # <--- GANTI NAMA KOLOM INI (misal: 'Usia_Tahun', 'Nilai_Depresiasi')
    if nama_kolom_num1_aset in df_aset_tetap.columns and nama_kolom_num2_aset in df_aset_tetap.columns \
       and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_num1_aset]) \
       and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_num2_aset]):
        plt.figure(figsize=(10, 6))
        # Menggunakan scatterplot untuk melihat relasi antara dua variabel numerik
        # Parameter 'hue' bisa ditambahkan jika ada kolom kategori untuk membedakan titik berdasarkan kategori
        sns.scatterplot(data=df_aset_tetap, x=nama_kolom_num1_aset, y=nama_kolom_num2_aset, color='teal', alpha=0.6) # Warna titik
        plt.title(f'Relasi antara {nama_kolom_num1_aset} dan {nama_kolom_num2_aset} Aset Tetap', fontsize=14)
        plt.xlabel(nama_kolom_num1_aset, fontsize=12)
        plt.ylabel(nama_kolom_num2_aset, fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()
    else:
        print(f"\nKolom numerik '{nama_kolom_num1_aset}' atau '{nama_kolom_num2_aset}' tidak ditemukan atau bukan numerik di df_aset_tetap. Lewati visualisasi scatter plot.")


    # Contoh visualisasi untuk Kebijakan Fiskal (Line Plot untuk tren waktu, jika ada kolom tanggal/tahun)
    # Ganti 'NamaKolomTanggalFiskal' dan 'NamaKolomNilaiFiskal' dengan nama kolom yang relevan
    # Contoh: 'Tahun' (tanggal/tahun) dan 'Anggaran' (nilai)
    nama_kolom_tanggal_fiskal = 'NamaKolomTanggalFiskal' # <--- GANTI NAMA KOLOM INI (misal: 'Tahun')
    nama_kolom_nilai_fiskal = 'NamaKolomNilaiFiskal'     # <--- GANTI NAMA KOLOM INI (misal: 'Anggaran')
    try:
        if nama_kolom_tanggal_fiskal in df_kebijakan_fiskal.columns and nama_kolom_nilai_fiskal in df_kebijakan_fiskal.columns:
            # Konversi kolom tanggal/tahun jika perlu
            # Contoh jika kolomnya hanya tahun (int atau string) dan Anda ingin menganggapnya sebagai tanggal
            try:
                 # Coba konversi ke datetime, anggap akhir tahun jika hanya tahun
                 df_kebijakan_fiskal['Tanggal_Konversi'] = pd.to_datetime(df_kebijakan_fiskal[nama_kolom_tanggal_fiskal], errors='coerce')
                 tanggal_col = 'Tanggal_Konversi'
            except:
                 # Jika konversi gagal, coba urutkan berdasarkan kolom asli jika numerik
                 if pd.api.types.is_numeric_dtype(df_kebijakan_fiskal[nama_kolom_tanggal_fiskal]):
                      df_kebijakan_fiskal_sorted = df_kebijakan_fiskal.sort_values(by=nama_kolom_tanggal_fiskal)
                      tanggal_col = nama_kolom_tanggal_fiskal # Tetap gunakan nama kolom asli untuk plot
                 else:
                     print(f"Kolom '{nama_kolom_tanggal_fiskal}' di df_kebijakan_fiskal bukan format tanggal/tahun yang dikenali atau numerik. Lewati visualisasi tren.")
                     tanggal_col = None # Tandai agar visualisasi dilewati


            if tanggal_col:
                # Jika berhasil dikonversi atau kolom aslinya numerik
                # Pastikan data diurutkan berdasarkan tanggal/tahun
                if tanggal_col != nama_kolom_tanggal_fiskal: # Jika pakai kolom konversi
                     df_kebijakan_fiskal.dropna(subset=[tanggal_col], inplace=True)
                     df_kebijakan_fiskal_sorted = df_kebijakan_fiskal.sort_values(by=tanggal_col)
                # else: # Jika pakai kolom asli yang sudah diurutkan di blok try
                     # Sorting sudah dilakukan

                plt.figure(figsize=(12, 7))
                # Menggunakan lineplot untuk melihat tren seiring waktu/tahun
                sns.lineplot(data=df_kebijakan_fiskal_sorted, x=tanggal_col, y=nama_kolom_nilai_fiskal, marker='o', linestyle='-', color='purple') # Warna garis
                plt.title(f'Tren {nama_kolom_nilai_fiskal} Kebijakan Fiskal dari Waktu ke Waktu', fontsize=14)
                plt.xlabel('Periode', fontsize=12) # Label x lebih umum
                plt.ylabel(nama_kolom_nilai_fiskal, fontsize=12)
                plt.grid(True, linestyle='--', alpha=0.6)
                plt.xticks(rotation=45, ha='right')
                plt.tight_layout()
                plt.show()

        else:
             print(f"\nSalah satu kolom ('{nama_kolom_tanggal_fiskal}' atau '{nama_kolom_nilai_fiskal}') tidak ditemukan di df_kebijakan_fiskal. Lewati visualisasi tren.")
    except Exception as e:
         print(f"\nError saat visualisasi tren df_kebijakan_fiskal: {e}")


    # Contoh visualisasi untuk Transaksi Keuangan (Bar Plot untuk melihat relasi Kategori vs Nilai)
    # Ganti 'NamaKolomKategoriKeuangan' dan 'NamaKolomNilaiKeuangan' dengan nama kolom yang relevan
    # Contoh: 'Jenis_Transaksi' (kategori) dan 'Jumlah' (nilai)
    nama_kolom_kategori_keuangan = 'NamaKolomKategoriKeuangan' # <--- GANTI NAMA KOLOM INI (misal: 'Jenis_Transaksi')
    nama_kolom_nilai_keuangan = 'NamaKolomNilaiKeuangan'     # <--- GANTI NAMA KOLOM INI (misal: 'Jumlah')
    try:
        if nama_kolom_kategori_keuangan in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan in df_transaksi_keuangan.columns:
             # Menggunakan palet warna seaborn untuk batang yang berbeda
            plt.figure(figsize=(10, 6))
            sns.barplot(data=df_transaksi_keuangan, x=nama_kolom_kategori_keuangan, y=nama_kolom_nilai_keuangan, palette='plasma') # Palet warna
            plt.title(f'Perbandingan {nama_kolom_nilai_keuangan} per {nama_kolom_kategori_keuangan} Transaksi Keuangan', fontsize=14)
            plt.xlabel(nama_kolom_kategori_keuangan, fontsize=12)
            plt.ylabel(nama_kolom_nilai_keuangan, fontsize=12)
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.grid(axis='y', linestyle='--', alpha=0.6)
            plt.show()
        else:
            print(f"\nSalah satu kolom ('{nama_kolom_kategori_keuangan}' atau '{nama_kolom_nilai_keuangan}') tidak ditemukan di df_transaksi_keuangan. Lewati visualisasi bar plot.")
    except Exception as e:
         print(f"\nError saat visualisasi bar plot df_transaksi_keuangan: {e}")


    # Analisis Komprehensif (Contoh lain visualisasi relasi/tren)
    print("\n" + "="*30)
    print("--- Analisis Komprehensif & Visualisasi Lanjutan ---")
    print("="*30)

    # Contoh: Matriks Korelasi antar kolom numerik di Aset Tetap (menggambarkan relasi)
    numeric_cols_aset = df_aset_tetap.select_dtypes(include=['number']).columns
    if len(numeric_cols_aset) > 1:
        print("\nMatriks Korelasi Aset Tetap:")
        # Visualisasi Korelasi (Heatmap) - Berwarna
        plt.figure(figsize=(8, 6))
        sns.heatmap(df_aset_tetap[numeric_cols_aset].corr(), annot=True, cmap='coolwarm', fmt=".2f") # cmap 'coolwarm' untuk warna
        plt.title('Matriks Korelasi Aset Tetap', fontsize=14)
        plt.show()
    else:
        print("\nTidak cukup kolom numerik di Aset Tetap untuk menghitung korelasi.")

    # Contoh: Analisis deret waktu pada Transaksi Keuangan (Line Plot dari data yang di-resample)
    # Ganti 'NamaKolomTanggalAnda' dan 'NamaKolomNilaiAnda' dengan nama kolom yang relevan
    # Menggunakan nama kolom yang sama seperti visualisasi line plot sebelumnya
    nama_kolom_tanggal_keuangan_ts = 'NamaKolomTanggalAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_keuangan_ts = 'NamaKolomNilaiAnda'     # <--- GANTI NAMA KOLOM INI
    try:
        if nama_kolom_tanggal_keuangan_ts in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan_ts in df_transaksi_keuangan.columns:
            df_transaksi_keuangan[nama_kolom_tanggal_keuangan_ts] = pd.to_datetime(df_transaksi_keuangan[nama_kolom_tanggal_keuangan_ts], errors='coerce')
            df_transaksi_keuangan.dropna(subset=[nama_kolom_tanggal_keuangan_ts], inplace=True)

            # Set kolom tanggal sebagai index untuk resampling
            df_transaksi_keuangan_ts = df_transaksi_keuangan.set_index(nama_kolom_tanggal_keuangan_ts)

            print(f"\nResampling Bulanan {nama_kolom_nilai_keuangan_ts} Transaksi Keuangan (Total Bulanan):")
            # Resampling bulanan, hitung total (sesuaikan 'sum()' jika perlu)
            resampled_data = df_transaksi_keuangan_ts[nama_kolom_nilai_keuangan_ts].resample('M').sum()
            # print(resampled_data.head()) # Opsional: tampilkan data yang di-resample

            # Visualisasi data yang di-resample - Berwarna
            plt.figure(figsize=(12, 7))
            resampled_data.plot(kind='line', marker='o', linestyle='-', color='teal') # Warna garis
            plt.title(f'Tren {nama_kolom_nilai_keuangan_ts} Transaksi Keuangan (Bulanan)', fontsize=14)
            plt.xlabel('Bulan', fontsize=12)
            plt.ylabel(f'Total {nama_kolom_nilai_keuangan_ts}', fontsize=12)
            plt.grid(True)
            plt.tight_layout()
            plt.show()

        else:
            print(f"Salah satu kolom ('{nama_kolom_tanggal_keuangan_ts}' atau '{nama_kolom_nilai_keuangan_ts}') tidak ditemukan untuk analisis deret waktu di df_transaksi_keuangan.")
    except Exception as e:
         print(f"Error saat analisis deret waktu df_transaksi_keuangan: {e}")


    print("\n" + "="*30)
    print("Visualisasi relasi dan tren selesai.")
    print("="*30)

else:
    print("\n--- Visualisasi Relasi dan Tren Dilewati Karena Gagal Memuat File ---")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# --- Visualisasi Relasi dan Tren Dilewati Karena Gagal Memuat File ---

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
    dataframes_loaded = True
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    dataframes_loaded = False
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    dataframes_loaded = False
    pass


# Analisis Kolom dan Informasi Dasar (Tetap ada untuk konteks, meskipun fokus pada visualisasi)
if dataframes_loaded:
    print("\n" + "="*30)
    print("--- Analisis Aset Tetap ---")
    print("="*30)
    display(df_aset_tetap.head())
    print(df_aset_tetap.info())
    print(df_aset_tetap.describe().to_string())
    print(df_aset_tetap.isnull().sum().to_string())

    print("\n" + "="*30)
    print("--- Analisis Kebijakan Fiskal ---")
    print("="*30)
    display(df_kebijakan_fiskal.head())
    print(df_kebijakan_fiskal.info())
    print(df_kebijakan_fiskal.describe().to_string())
    print(df_kebijakan_fiskal.isnull().sum().to_string())

    print("\n" + "="*30)
    print("--- Analisis Transaksi Keuangan ---")
    print("="*30)
    display(df_transaksi_keuangan.head())
    print(df_transaksi_keuangan.info())
    print(df_transaksi_keuangan.describe().to_string())
    print(df_transaksi_keuangan.isnull().sum().to_string())


    # Visualisasi Data untuk Relasi dan Tren (Grafik Berwarna)
    print("\n" + "="*30)
    print("--- Visualisasi Relasi dan Tren Data ---")
    print("="*30)

    # Visualisasi untuk Aset Tetap (Contoh: Scatter Plot jika ada 2 kolom numerik untuk melihat relasi)
    # Ganti 'NamaKolomNumerik1' dan 'NamaKolomNumerik2' dengan nama kolom numerik yang ingin Anda lihat relasinya
    nama_kolom_num1_aset = 'NamaKolomNumerik1' # <--- GANTI NAMA KOLOM INI (misal: 'Jumlah', 'Nilai')
    nama_kolom_num2_aset = 'NamaKolomNumerik2' # <--- GANTI NAMA KOLOM INI (misal: 'Usia_Tahun', 'Nilai_Depresiasi')
    if nama_kolom_num1_aset in df_aset_tetap.columns and nama_kolom_num2_aset in df_aset_tetap.columns \
       and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_num1_aset]) \
       and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_num2_aset]):
        plt.figure(figsize=(10, 6))
        # Menggunakan scatterplot untuk melihat relasi antara dua variabel numerik
        # Parameter 'hue' bisa ditambahkan jika ada kolom kategori untuk membedakan titik berdasarkan kategori
        sns.scatterplot(data=df_aset_tetap, x=nama_kolom_num1_aset, y=nama_kolom_num2_aset, color='teal', alpha=0.6) # Warna titik
        plt.title(f'Relasi antara {nama_kolom_num1_aset} dan {nama_kolom_num2_aset} Aset Tetap', fontsize=14)
        plt.xlabel(nama_kolom_num1_aset, fontsize=12)
        plt.ylabel(nama_kolom_num2_aset, fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()
    else:
        print(f"\nKolom numerik '{nama_kolom_num1_aset}' atau '{nama_kolom_num2_aset}' tidak ditemukan atau bukan numerik di df_aset_tetap. Lewati visualisasi scatter plot.")


    # Contoh visualisasi untuk Kebijakan Fiskal (Line Plot untuk tren waktu, jika ada kolom tanggal/tahun)
    # Ganti 'NamaKolomTanggalFiskal' dan 'NamaKolomNilaiFiskal' dengan nama kolom yang relevan
    # Contoh: 'Tahun' (tanggal/tahun) dan 'Anggaran' (nilai)
    nama_kolom_tanggal_fiskal = 'NamaKolomTanggalFiskal' # <--- GANTI NAMA KOLOM INI (misal: 'Tahun')
    nama_kolom_nilai_fiskal = 'NamaKolomNilaiFiskal'     # <--- GANTI NAMA KOLOM INI (misal: 'Anggaran')
    try:
        if nama_kolom_tanggal_fiskal in df_kebijakan_fiskal.columns and nama_kolom_nilai_fiskal in df_kebijakan_fiskal.columns:
            # Konversi kolom tanggal/tahun jika perlu
            # Contoh jika kolomnya hanya tahun (int atau string) dan Anda ingin menganggapnya sebagai tanggal
            try:
                 # Coba konversi ke datetime, anggap akhir tahun jika hanya tahun
                 df_kebijakan_fiskal['Tanggal_Konversi'] = pd.to_datetime(df_kebijakan_fiskal[nama_kolom_tanggal_fiskal], errors='coerce')
                 tanggal_col = 'Tanggal_Konversi'
            except:
                 # Jika konversi gagal, coba urutkan berdasarkan kolom asli jika numerik
                 if pd.api.types.is_numeric_dtype(df_kebijakan_fiskal[nama_kolom_tanggal_fiskal]):
                      df_kebijakan_fiskal_sorted = df_kebijakan_fiskal.sort_values(by=nama_kolom_tanggal_fiskal)
                      tanggal_col = nama_kolom_tanggal_fiskal # Tetap gunakan nama kolom asli untuk plot
                 else:
                     print(f"Kolom '{nama_kolom_tanggal_fiskal}' di df_kebijakan_fiskal bukan format tanggal/tahun yang dikenali atau numerik. Lewati visualisasi tren.")
                     tanggal_col = None # Tandai agar visualisasi dilewati


            if tanggal_col:
                # Jika berhasil dikonversi atau kolom aslinya numerik
                # Pastikan data diurutkan berdasarkan tanggal/tahun
                if tanggal_col != nama_kolom_tanggal_fiskal: # Jika pakai kolom konversi
                     df_kebijakan_fiskal.dropna(subset=[tanggal_col], inplace=True)
                     df_kebijakan_fiskal_sorted = df_kebijakan_fiskal.sort_values(by=tanggal_col)
                # else: # Jika pakai kolom asli yang sudah diurutkan di blok try
                     # Sorting sudah dilakukan

                plt.figure(figsize=(12, 7))
                # Menggunakan lineplot untuk melihat tren seiring waktu/tahun
                sns.lineplot(data=df_kebijakan_fiskal_sorted, x=tanggal_col, y=nama_kolom_nilai_fiskal, marker='o', linestyle='-', color='purple') # Warna garis
                plt.title(f'Tren {nama_kolom_nilai_fiskal} Kebijakan Fiskal dari Waktu ke Waktu', fontsize=14)
                plt.xlabel('Periode', fontsize=12) # Label x lebih umum
                plt.ylabel(nama_kolom_nilai_fiskal, fontsize=12)
                plt.grid(True, linestyle='--', alpha=0.6)
                plt.xticks(rotation=45, ha='right')
                plt.tight_layout()
                plt.show()

        else:
             print(f"\nSalah satu kolom ('{nama_kolom_tanggal_fiskal}' atau '{nama_kolom_nilai_fiskal}') tidak ditemukan di df_kebijakan_fiskal. Lewati visualisasi tren.")
    except Exception as e:
         print(f"\nError saat visualisasi tren df_kebijakan_fiskal: {e}")


    # Contoh visualisasi untuk Transaksi Keuangan (Bar Plot untuk melihat relasi Kategori vs Nilai)
    # Ganti 'NamaKolomKategoriKeuangan' dan 'NamaKolomNilaiKeuangan' dengan nama kolom yang relevan
    # Contoh: 'Jenis_Transaksi' (kategori) dan 'Jumlah' (nilai)
    nama_kolom_kategori_keuangan = 'NamaKolomKategoriKeuangan' # <--- GANTI NAMA KOLOM INI (misal: 'Jenis_Transaksi')
    nama_kolom_nilai_keuangan = 'NamaKolomNilaiKeuangan'     # <--- GANTI NAMA KOLOM INI (misal: 'Jumlah')
    try:
        if nama_kolom_kategori_keuangan in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan in df_transaksi_keuangan.columns:
             # Menggunakan palet warna seaborn untuk batang yang berbeda
            plt.figure(figsize=(10, 6))
            sns.barplot(data=df_transaksi_keuangan, x=nama_kolom_kategori_keuangan, y=nama_kolom_nilai_keuangan, palette='plasma') # Palet warna
            plt.title(f'Perbandingan {nama_kolom_nilai_keuangan} per {nama_kolom_kategori_keuangan} Transaksi Keuangan', fontsize=14)
            plt.xlabel(nama_kolom_kategori_keuangan, fontsize=12)
            plt.ylabel(nama_kolom_nilai_keuangan, fontsize=12)
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.grid(axis='y', linestyle='--', alpha=0.6)
            plt.show()
        else:
            print(f"\nSalah satu kolom ('{nama_kolom_kategori_keuangan}' atau '{nama_kolom_nilai_keuangan}') tidak ditemukan di df_transaksi_keuangan. Lewati visualisasi bar plot.")
    except Exception as e:
         print(f"\nError saat visualisasi bar plot df_transaksi_keuangan: {e}")


    # Analisis Komprehensif (Contoh lain visualisasi relasi/tren)
    print("\n" + "="*30)
    print("--- Analisis Komprehensif & Visualisasi Lanjutan ---")
    print("="*30)

    # Contoh: Matriks Korelasi antar kolom numerik di Aset Tetap (menggambarkan relasi)
    numeric_cols_aset = df_aset_tetap.select_dtypes(include=['number']).columns
    if len(numeric_cols_aset) > 1:
        print("\nMatriks Korelasi Aset Tetap:")
        # Visualisasi Korelasi (Heatmap) - Berwarna
        plt.figure(figsize=(8, 6))
        sns.heatmap(df_aset_tetap[numeric_cols_aset].corr(), annot=True, cmap='coolwarm', fmt=".2f") # cmap 'coolwarm' untuk warna
        plt.title('Matriks Korelasi Aset Tetap', fontsize=14)
        plt.show()
    else:
        print("\nTidak cukup kolom numerik di Aset Tetap untuk menghitung korelasi.")

    # Contoh: Analisis deret waktu pada Transaksi Keuangan (Line Plot dari data yang di-resample)
    # Ganti 'NamaKolomTanggalAnda' dan 'NamaKolomNilaiAnda' dengan nama kolom yang relevan
    # Menggunakan nama kolom yang sama seperti visualisasi line plot sebelumnya
    nama_kolom_tanggal_keuangan_ts = 'NamaKolomTanggalAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_keuangan_ts = 'NamaKolomNilaiAnda'     # <--- GANTI NAMA KOLOM INI
    try:
        if nama_kolom_tanggal_keuangan_ts in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan_ts in df_transaksi_keuangan.columns:
            df_transaksi_keuangan[nama_kolom_tanggal_keuangan_ts] = pd.to_datetime(df_transaksi_keuangan[nama_kolom_tanggal_keuangan_ts], errors='coerce')
            df_transaksi_keuangan.dropna(subset=[nama_kolom_tanggal_keuangan_ts], inplace=True)

            # Set kolom tanggal sebagai index untuk resampling
            df_transaksi_keuangan_ts = df_transaksi_keuangan.set_index(nama_kolom_tanggal_keuangan_ts)

            print(f"\nResampling Bulanan {nama_kolom_nilai_keuangan_ts} Transaksi Keuangan (Total Bulanan):")
            # Resampling bulanan, hitung total (sesuaikan 'sum()' jika perlu)
            resampled_data = df_transaksi_keuangan_ts[nama_kolom_nilai_keuangan_ts].resample('M').sum()
            # print(resampled_data.head()) # Opsional: tampilkan data yang di-resample

            # Visualisasi data yang di-resample - Berwarna
            plt.figure(figsize=(12, 7))
            resampled_data.plot(kind='line', marker='o', linestyle='-', color='teal') # Warna garis
            plt.title(f'Tren {nama_kolom_nilai_keuangan_ts} Transaksi Keuangan (Bulanan)', fontsize=14)
            plt.xlabel('Bulan', fontsize=12)
            plt.ylabel(f'Total {nama_kolom_nilai_keuangan_ts}', fontsize=12)
            plt.grid(True)
            plt.tight_layout()
            plt.show()

        else:
            print(f"Salah satu kolom ('{nama_kolom_tanggal_keuangan_ts}' atau '{nama_kolom_nilai_keuangan_ts}') tidak ditemukan untuk analisis deret waktu di df_transaksi_keuangan.")
    except Exception as e:
         print(f"Error saat analisis deret waktu df_transaksi_keuangan: {e}")


    print("\n" + "="*30)
    print("Visualisasi relasi dan tren selesai.")
    print("="*30)

else:
    print("\n--- Visualisasi Relasi dan Tren Dilewati Karena Gagal Memuat File ---")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# --- Visualisasi Relasi dan Tren Dilewati Karena Gagal Memuat File ---

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
    dataframes_loaded = True
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    dataframes_loaded = False
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    dataframes_loaded = False
    pass


# Analisis Mendalam Per Kolom (Termasuk Visualisasi Distribusi Berwarna)
if dataframes_loaded: # Hanya lakukan analisis jika dataframe berhasil dimuat

    # --- Analisis Mendalam Aset Tetap ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Aset Tetap ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_aset_tetap.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    # Menggunakan to_string() agar semua baris describe terlihat
    print(df_aset_tetap.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_aset_tetap.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_aset_tetap.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_aset_tetap[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_aset_tetap[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_aset_tetap[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_aset_tetap[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_aset_tetap[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1) # 1 baris, 2 kolom, plot ke-1
            sns.histplot(data=df_aset_tetap, x=col, kde=True, color='skyblue') # Warna Histogram
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2) # 1 baris, 2 kolom, plot ke-2
            sns.boxplot(data=df_aset_tetap, x=col, color='lightcoral') # Warna Box Plot
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)


            plt.tight_layout() # Menyesuaikan layout agar tidak tumpang tindih
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_aset_tetap[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_aset_tetap[col].min()}")
                 print(f"Tanggal Terakhir: {df_aset_tetap[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_aset_tetap[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_aset_tetap[col].nunique() <= 20: # Batas arbitrer untuk visualisasi count plot
                 plt.figure(figsize=(10, 6))
                 # Menggunakan palette untuk warna batang yang berbeda
                 sns.countplot(data=df_aset_tetap, y=col, order=df_aset_tetap[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_aset_tetap[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_aset_tetap[col].nunique()}) untuk visualisasi count plot.")


    # --- Analisis Mendalam Kebijakan Fiskal ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Kebijakan Fiskal ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_kebijakan_fiskal.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_kebijakan_fiskal.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_kebijakan_fiskal.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_kebijakan_fiskal.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_kebijakan_fiskal[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_kebijakan_fiskal[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_kebijakan_fiskal[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_kebijakan_fiskal[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_kebijakan_fiskal[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_kebijakan_fiskal, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_kebijakan_fiskal, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_kebijakan_fiskal[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_kebijakan_fiskal[col].min()}")
                 print(f"Tanggal Terakhir: {df_kebijakan_fiskal[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_kebijakan_fiskal[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_kebijakan_fiskal[col].nunique() <= 20: # Batas arbitrer
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_kebijakan_fiskal, y=col, order=df_kebijakan_fiskal[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_kebijakan_fiskal[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_kebijakan_fiskal[col].nunique()}) untuk visualisasi count plot.")


    # --- Analisis Mendalam Transaksi Keuangan ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Transaksi Keuangan ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_transaksi_keuangan.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_transaksi_keuangan.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_transaksi_keuangan.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_transaksi_keuangan.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_transaksi_keuangan[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_transaksi_keuangan[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_transaksi_keuangan[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_transaksi_keuangan[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_transaksi_keuangan[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_transaksi_keuangan, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_transaksi_keuangan, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_transaksi_keuangan[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_transaksi_keuangan[col].min()}")
                 print(f"Tanggal Terakhir: {df_transaksi_keuangan[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_transaksi_keuangan[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_transaksi_keuangan[col].nunique() <= 20: # Batas arbitrer
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_transaksi_keuangan, y=col, order=df_transaksi_keuangan[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_transaksi_keuangan[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_transaksi_keuangan[col].nunique()}) untuk visualisasi count plot.")
            else: # Add a default message if the column type is not handled or visualization is skipped
                 print(f"Kolom '{col}' memiliki tipe data {df_transaksi_keuangan[col].dtype} dan visualisasi distribusi dilewati.")


    print("\n" + "="*40)
    print("Analisis mendalam selesai.")
    print("="*40)


else:
    print("\n--- Analisis Mendalam dan Visualisasi Dilewati Karena Gagal Memuat File ---")

# The duplicated code block that caused the error was removed from here.
# Any code that should run after the data loading and initial checks should be placed here, outside the 'if dataframes_loaded:' block,
# or inside a new block that checks for dataframes_loaded.

# Example of placing subsequent visualisations/analysis here if they should run
# after the data loading but are not part of the per-column analysis loop.
# You can uncomment and adapt the following sections if needed, ensuring they are
# correctly placed and indented.

# # Visualisasi Hubungan/Tren Lanjutan (Grafik Berwarna)
# if dataframes_loaded:
#     print("\n" + "="*30)
#     print("--- Visualisasi Relasi dan Tren Data ---")
#     print("="*30)

#     # Visualisasi untuk Aset Tetap (Contoh: Scatter Plot)
#     nama_kolom_num1_aset = 'NamaKolomNumerik1'
#     nama_kolom_num2_aset = 'NamaKolomNumerik2'
#     if nama_kolom_num1_aset in df_aset_tetap.columns and nama_kolom_num2_aset in df_aset_tetap.columns \
#        and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_num1_aset]) \
#        and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_num2_aset]):
#         plt.figure(figsize=(10, 6))
#         sns.scatterplot(data=df_aset_tetap, x=nama_kolom_num1_aset, y=nama_kolom_num2_aset, color='teal', alpha=0.6)
#         plt.title(f'Relasi antara {nama_kolom_num1_aset} dan {nama_kolom_num2_aset} Aset Tetap', fontsize=14)
#         plt.xlabel(nama_kolom_num1_aset, fontsize=12)
#         plt.ylabel(nama_kolom_num2_aset, fontsize=12)
#         plt.grid(True, linestyle='--', alpha=0.6)
#         plt.show()
#     else:
#         print(f"\nKolom numerik '{nama_kolom_num1_aset}' atau '{nama_kolom_num2_aset}' tidak ditemukan atau bukan numerik di df_aset_tetap. Lewati visualisasi scatter plot.")

#     # ... (lanjutkan dengan visualisasi lain untuk Kebijakan Fiskal, Transaksi Keuangan, dll.)

#     print("\n" + "="*30)
#     print("Visualisasi relasi dan tren selesai.")
#     print("="*30)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# --- Analisis Mendalam dan Visualisasi Dilewati Karena Gagal Memuat File ---

# %%
# Import library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # Digunakan untuk sys.exit()
from google.colab import drive # Untuk mount Google Drive di Colab
# Import display untuk tampilan head() yang lebih baik di notebook
from IPython.display import display

# Mount Google Drive (Opsional, jika Anda menggunakan Google Colab dan file ada di Drive)
# Jika file CSV Anda berada di lingkungan lokal atau di root Colab, Anda bisa mengabaikan baris ini.
drive.mount('/content/drive') # Pastikan baris ini tidak dikomentari jika file ada di Drive
# Jika Anda mount Drive, ganti path file CSV di bawah dengan path di Drive Anda,
# misalnya: "/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv"

# Muat data dari file CSV
try:
    # Pastikan file-file ini ('Tabel-Aset-Tetap.csv', 'Tabel-Kebijakan-Fiskal.csv', 'Tabel-Transaksi-Keuangan.csv')
    # berada di direktori yang sama dengan notebook ini, atau ganti string dengan path lengkapnya.

    # >>> UBAH PATH FILE DI BAWAH SESUAI LOKASI FILE DI GOOGLE DRIVE ANDA <<<
    # Ganti 'NamaFolderAnda' dengan nama folder Anda yang sebenarnya
    # Pastikan juga nama file CSV sudah benar
    df_aset_tetap = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv")
    df_kebijakan_fiskal = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Kebijakan-Fiskal.csv")
    df_transaksi_keuangan = pd.read_csv("/content/drive/My Drive/NamaFolderAnda/Tabel-Transaksi-Keuangan.csv")

    print("File CSV berhasil dimuat.")
    dataframes_loaded = True
except FileNotFoundError as e:
    print(f"Error: {e}. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.")
    dataframes_loaded = False
    pass # Ganti sys.exit(1) dengan pass atau raise jika Anda ingin melihat lebih banyak output error di notebook
except Exception as e:
    print(f"Terjadi error saat memuat file CSV: {e}")
    dataframes_loaded = False
    pass


# Analisis Mendalam Per Kolom (Termasuk Visualisasi Distribusi Berwarna) - Kode ini tetap sama
if dataframes_loaded: # Hanya lakukan analisis jika dataframe berhasil dimuat

    # --- Analisis Mendalam Aset Tetap ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Aset Tetap ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_aset_tetap.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    # Menggunakan to_string() agar semua baris describe terlihat
    print(df_aset_tetap.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_aset_tetap.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_aset_tetap.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_aset_tetap[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_aset_tetap[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_aset_tetap[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_aset_tetap[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_aset_tetap[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1) # 1 baris, 2 kolom, plot ke-1
            sns.histplot(data=df_aset_tetap, x=col, kde=True, color='skyblue') # Warna Histogram
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2) # 1 baris, 2 kolom, plot ke-2
            sns.boxplot(data=df_aset_tetap, x=col, color='lightcoral') # Warna Box Plot
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)


            plt.tight_layout() # Menyesuaikan layout agar tidak tumpang tindih
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_aset_tetap[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_aset_tetap[col].min()}")
                 print(f"Tanggal Terakhir: {df_aset_tetap[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_aset_tetap[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_aset_tetap[col].nunique() <= 20: # Batas arbitrer untuk visualisasi count plot
                 plt.figure(figsize=(10, 6))
                 # Menggunakan palette untuk warna batang yang berbeda
                 sns.countplot(data=df_aset_tetap, y=col, order=df_aset_tetap[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_aset_tetap[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_aset_tetap[col].nunique()}) untuk visualisasi count plot.")
            else: # Add a default message if the column type is not handled or visualization is skipped
                 print(f"Kolom '{col}' memiliki tipe data {df_aset_tetap[col].dtype} dan visualisasi distribusi dilewati.")


    # --- Analisis Mendalam Kebijakan Fiskal ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Kebijakan Fiskal ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_kebijakan_fiskal.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_kebijakan_fiskal.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_kebijakan_fiskal.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_kebijakan_fiskal.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_kebijakan_fiskal[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_kebijakan_fiskal[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_kebijakan_fiskal[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_kebijakan_fiskal[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_kebijakan_fiskal[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_kebijakan_fiskal, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_kebijakan_fiskal, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_kebijakan_fiskal[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_kebijakan_fiskal[col].min()}")
                 print(f"Tanggal Terakhir: {df_kebijakan_fiskal[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_kebijakan_fiskal[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_kebijakan_fiskal[col].nunique() <= 20: # Batas arbitrer
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_kebijakan_fiskal, y=col, order=df_kebijakan_fiskal[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_kebijakan_fiskal[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_kebijakan_fiskal[col].nunique()}) untuk visualisasi count plot.")
            else:
                 print(f"Kolom '{col}' memiliki tipe data {df_kebijakan_fiskal[col].dtype} dan visualisasi distribusi dilewati.")


    # --- Analisis Mendalam Transaksi Keuangan ---
    print("\n" + "="*40)
    print("--- Analisis Mendalam: Transaksi Keuangan ---")
    print("="*40)

    print("\nInformasi Dasar (Tipe Data, Non-Null Counts):")
    df_transaksi_keuangan.info()

    print("\nStatistik Deskriptif untuk Kolom Numerik:")
    print(df_transaksi_keuangan.describe().to_string())

    print("\nJumlah Nilai yang Hilang per Kolom:")
    print(df_transaksi_keuangan.isnull().sum().to_string())

    print("\nAnalisis Kolom Individu dan Visualisasi Distribusi:")
    for col in df_transaksi_keuangan.columns:
        print(f"\n--- Kolom: {col} ---")
        print(f"Tipe Data: {df_transaksi_keuangan[col].dtype}")
        print(f"Jumlah Nilai Hilang: {df_transaksi_keuangan[col].isnull().sum()}")
        print(f"Jumlah Nilai Unik: {df_transaksi_keuangan[col].nunique()}")

        # Analisis Distribusi berdasarkan Tipe Data
        if pd.api.types.is_numeric_dtype(df_transaksi_keuangan[col]):
            print("Distribusi Numerik:")
            # Statistik tambahan untuk kolom numerik (mean, median, std, skew, kurtosis)
            print(df_transaksi_keuangan[col].agg(['mean', 'median', 'std', 'min', 'max', 'skew', 'kurtosis']).to_string())

            # Visualisasi Distribusi Numerik (Histogram dan Box Plot) - Berwarna
            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            sns.histplot(data=df_transaksi_keuangan, x=col, kde=True, color='skyblue')
            plt.title(f'Histogram Distribusi {col}')
            plt.xlabel(col)
            plt.ylabel('Frekuensi')
            plt.grid(axis='y', alpha=0.5)

            plt.subplot(1, 2, 2)
            sns.boxplot(data=df_transaksi_keuangan, x=col, color='lightcoral')
            plt.title(f'Box Plot Distribusi {col}')
            plt.xlabel(col)
            plt.grid(axis='x', alpha=0.5)

            plt.tight_layout()
            plt.show()

        elif pd.api.types.is_datetime64_any_dtype(df_transaksi_keuangan[col]):
             print("Informasi Kolom Tanggal/Waktu:")
             # Tampilkan rentang tanggal jika ada
             try:
                 print(f"Tanggal Terawal: {df_transaksi_keuangan[col].min()}")
                 print(f"Tanggal Terakhir: {df_transaksi_keuangan[col].max()}")
             except:
                 print("Tidak dapat menentukan rentang tanggal.")

        else: # Kolom Kategorikal atau Objek
            print("Distribusi Kategorikal (Top 10 Frekuensi):")
            # Tampilkan 10 nilai unik teratas dan frekuensinya
            print(df_transaksi_keuangan[col].value_counts().head(10).to_string())

            # Jika jumlah unik tidak terlalu banyak, bisa divisualisasikan
            if df_transaksi_keuangan[col].nunique() <= 20: # Batas arbitrer
                 plt.figure(figsize=(10, 6))
                 sns.countplot(data=df_transaksi_keuangan, y=col, order=df_transaksi_keuangan[col].value_counts().index, palette='viridis')
                 plt.title(f'Frekuensi per Kategori: {col}')
                 plt.xlabel('Frekuensi')
                 plt.ylabel(col)
                 plt.grid(axis='x', alpha=0.5)
                 plt.tight_layout()
                 plt.show()
            elif df_transaksi_keuangan[col].nunique() > 20:
                 print(f"Terlalu banyak nilai unik ({df_transaksi_keuangan[col].nunique()}) untuk visualisasi count plot.")
            else:
                 print(f"Kolom '{col}' memiliki tipe data {df_transaksi_keuangan[col].dtype} dan visualisasi distribusi dilewati.")


    print("\n" + "="*40)
    print("Analisis mendalam selesai.")
    print("="*40)


    # ========================================================================
    # Bagian Visualisasi Hubungan dan Tren (Grafik Berwarna)
    # Ditempatkan di sini setelah analisis per kolom
    # ========================================================================
    print("\n" + "="*40)
    print("--- Visualisasi Relasi dan Tren Data ---")
    print("="*40)

    # Visualisasi untuk Aset Tetap (Contoh: Scatter Plot jika ada 2 kolom numerik untuk melihat relasi)
    # Ganti 'NamaKolomNumerik1' dan 'NamaKolomNumerik2' dengan nama kolom numerik yang ingin Anda lihat relasinya
    nama_kolom_num1_aset = 'NamaKolomNumerik1' # <--- GANTI NAMA KOLOM INI (misal: 'Jumlah', 'Nilai')
    nama_kolom_num2_aset = 'NamaKolomNumerik2' # <--- GANTI NAMA KOLOM INI (misal: 'Usia_Tahun', 'Nilai_Depresiasi')
    if nama_kolom_num1_aset in df_aset_tetap.columns and nama_kolom_num2_aset in df_aset_tetap.columns \
       and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_num1_aset]) \
       and pd.api.types.is_numeric_dtype(df_aset_tetap[nama_kolom_num2_aset]):
        plt.figure(figsize=(10, 6))
        # Menggunakan scatterplot untuk melihat relasi antara dua variabel numerik
        # Parameter 'hue' bisa ditambahkan jika ada kolom kategori untuk membedakan titik berdasarkan kategori
        # sns.scatterplot(data=df_aset_tetap, x=nama_kolom_num1_aset, y=nama_kolom_num2_aset, hue='NamaKolomKategoriOpsional', palette='viridis', alpha=0.7) # Contoh dengan hue
        sns.scatterplot(data=df_aset_tetap, x=nama_kolom_num1_aset, y=nama_kolom_num2_aset, color='teal', alpha=0.6) # Warna titik tunggal
        plt.title(f'Relasi antara {nama_kolom_num1_aset} dan {nama_kolom_num2_aset} Aset Tetap', fontsize=14)
        plt.xlabel(nama_kolom_num1_aset, fontsize=12)
        plt.ylabel(nama_kolom_num2_aset, fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.show()
    else:
        print(f"\nKolom numerik '{nama_kolom_num1_aset}' atau '{nama_kolom_num2_aset}' tidak ditemukan atau bukan numerik di df_aset_tetap. Lewati visualisasi scatter plot.")


    # Contoh visualisasi untuk Kebijakan Fiskal (Line Plot untuk tren waktu, jika ada kolom tanggal/tahun)
    # Ganti 'NamaKolomTanggalFiskal' dan 'NamaKolomNilaiFiskal' dengan nama kolom yang relevan
    # Contoh: 'Tahun' (tanggal/tahun) dan 'Anggaran' (nilai)
    nama_kolom_tanggal_fiskal = 'NamaKolomTanggalFiskal' # <--- GANTI NAMA KOLOM INI (misal: 'Tahun')
    nama_kolom_nilai_fiskal = 'NamaKolomNilaiFiskal'     # <--- GANTI NAMA KOLOM INI (misal: 'Anggaran')
    try:
        if nama_kolom_tanggal_fiskal in df_kebijakan_fiskal.columns and nama_kolom_nilai_fiskal in df_kebijakan_fiskal.columns:
            # Konversi kolom tanggal/tahun jika perlu
            # Contoh jika kolomnya hanya tahun (int atau string) dan Anda ingin menganggapnya sebagai tanggal
            try:
                 # Coba konversi ke datetime, anggap akhir tahun jika hanya tahun
                 df_kebijakan_fiskal['Tanggal_Konversi'] = pd.to_datetime(df_kebijakan_fiskal[nama_kolom_tanggal_fiskal], errors='coerce')
                 tanggal_col = 'Tanggal_Konversi'
            except:
                 # Jika konversi gagal, coba urutkan berdasarkan kolom asli jika numerik
                 if pd.api.types.is_numeric_dtype(df_kebijakan_fiskal[nama_kolom_tanggal_fiskal]):
                      df_kebijakan_fiskal_sorted = df_kebijakan_fiskal.sort_values(by=nama_kolom_tanggal_fiskal)
                      tanggal_col = nama_kolom_tanggal_fiskal # Tetap gunakan nama kolom asli untuk plot
                 else:
                     print(f"Kolom '{nama_kolom_tanggal_fiskal}' di df_kebijakan_fiskal bukan format tanggal/tahun yang dikenali atau numerik. Lewati visualisasi tren.")
                     tanggal_col = None # Tandai agar visualisasi dilewati


            if tanggal_col:
                # Jika berhasil dikonversi atau kolom aslinya numerik
                # Pastikan data diurutkan berdasarkan tanggal/tahun
                if tanggal_col != nama_kolom_tanggal_fiskal: # Jika pakai kolom konversi
                     df_kebijakan_fiskal.dropna(subset=[tanggal_col], inplace=True)
                     df_kebijakan_fiskal_sorted = df_kebijakan_fiskal.sort_values(by=tanggal_col)
                else:
                    df_kebijakan_fiskal_sorted = df_kebijakan_fiskal.sort_values(by=tanggal_col)


                plt.figure(figsize=(12, 7))
                # Menggunakan lineplot untuk melihat tren seiring waktu/tahun
                sns.lineplot(data=df_kebijakan_fiskal_sorted, x=tanggal_col, y=nama_kolom_nilai_fiskal, marker='o', linestyle='-', color='purple') # Warna garis
                plt.title(f'Tren {nama_kolom_nilai_fiskal} Kebijakan Fiskal dari Waktu ke Waktu', fontsize=14)
                plt.xlabel('Periode', fontsize=12) # Label x lebih umum
                plt.ylabel(nama_kolom_nilai_fiskal, fontsize=12)
                plt.grid(True, linestyle='--', alpha=0.6)
                plt.xticks(rotation=45, ha='right')
                plt.tight_layout()
                plt.show()

        else:
             print(f"\nSalah satu kolom ('{nama_kolom_tanggal_fiskal}' atau '{nama_kolom_nilai_fiskal}') tidak ditemukan di df_kebijakan_fiskal. Lewati visualisasi tren.")
    except Exception as e:
         print(f"\nError saat visualisasi tren df_kebijakan_fiskal: {e}")


    # Contoh visualisasi untuk Transaksi Keuangan (Bar Plot untuk melihat relasi Kategori vs Nilai)
    # Ganti 'NamaKolomKategoriKeuangan' dan 'NamaKolomNilaiKeuangan' dengan nama kolom yang relevan
    # Contoh: 'Jenis_Transaksi' (kategori) dan 'Jumlah' (nilai)
    nama_kolom_kategori_keuangan = 'NamaKolomKategoriKeuangan' # <--- GANTI NAMA KOLOM INI (misal: 'Jenis_Transaksi')
    nama_kolom_nilai_keuangan = 'NamaKolomNilaiKeuangan'     # <--- GANTI NAMA KOLOM INI (misal: 'Jumlah')
    try:
        if nama_kolom_kategori_keuangan in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan in df_transaksi_keuangan.columns:
             # Menggunakan palet warna seaborn untuk batang yang berbeda
            plt.figure(figsize=(10, 6))
            # Hitung agregasi total nilai per kategori jika perlu, atau plot data mentah jika setiap baris adalah 1 transaksi
            # Contoh agregasi:
            # agregasi_keuangan = df_transaksi_keuangan.groupby(nama_kolom_kategori_keuangan)[nama_kolom_nilai_keuangan].sum().reset_index()
            # sns.barplot(data=agregasi_keuangan, x=nama_kolom_kategori_keuangan, y=nama_kolom_nilai_keuangan, palette='plasma')

            # Contoh menggunakan data mentah (jika setiap baris adalah satu transaksi yang akan dijumlahkan oleh barplot)
            sns.barplot(data=df_transaksi_keuangan, x=nama_kolom_kategori_keuangan, y=nama_kolom_nilai_keuangan, palette='plasma') # Palet warna
            plt.title(f'Total {nama_kolom_nilai_keuangan} per {nama_kolom_kategori_keuangan} Transaksi Keuangan', fontsize=14) # Judul diperbarui
            plt.xlabel(nama_kolom_kategori_keuangan, fontsize=12)
            plt.ylabel(f'Total {nama_kolom_nilai_keuangan}', fontsize=12) # Label y diperbarui
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.grid(axis='y', linestyle='--', alpha=0.6)
            plt.show()
        else:
            print(f"\nSalah satu kolom ('{nama_kolom_kategori_keuangan}' atau '{nama_kolom_nilai_keuangan}') tidak ditemukan di df_transaksi_keuangan. Lewati visualisasi bar plot.")
    except Exception as e:
         print(f"\nError saat visualisasi bar plot df_transaksi_keuangan: {e}")


    # Analisis Komprehensif (Contoh lain visualisasi relasi/tren) - Matriks Korelasi
    print("\n" + "="*40)
    print("--- Matriks Korelasi Aset Tetap (Visualisasi) ---")
    print("="*40)

    # Contoh: Matriks Korelasi antar kolom numerik di Aset Tetap (menggambarkan relasi)
    numeric_cols_aset = df_aset_tetap.select_dtypes(include=['number']).columns
    if len(numeric_cols_aset) > 1:
        print("\nMatriks Korelasi Aset Tetap:")
        # Visualisasi Korelasi (Heatmap) - Berwarna
        plt.figure(figsize=(8, 6))
        sns.heatmap(df_aset_tetap[numeric_cols_aset].corr(), annot=True, cmap='coolwarm', fmt=".2f") # cmap 'coolwarm' untuk warna
        plt.title('Matriks Korelasi Aset Tetap', fontsize=14)
        plt.show()
    else:
        print("\nTidak cukup kolom numerik di Aset Tetap untuk menghitung korelasi.")

    # Contoh: Analisis deret waktu pada Transaksi Keuangan (Line Plot dari data yang di-resample)
    print("\n" + "="*40)
    print("--- Analisis Deret Waktu Transaksi Keuangan (Visualisasi) ---")
    print("="*40)

    # Ganti 'NamaKolomTanggalAnda' dan 'NamaKolomNilaiAnda' dengan nama kolom yang relevan
    # Menggunakan nama kolom yang sama seperti visualisasi line plot sebelumnya
    nama_kolom_tanggal_keuangan_ts = 'NamaKolomTanggalAnda' # <--- GANTI NAMA KOLOM INI
    nama_kolom_nilai_keuangan_ts = 'NamaKolomNilaiAnda'     # <--- GANTI NAMA KOLOM INI
    try:
        if nama_kolom_tanggal_keuangan_ts in df_transaksi_keuangan.columns and nama_kolom_nilai_keuangan_ts in df_transaksi_keuangan.columns:
            df_transaksi_keuangan[nama_kolom_tanggal_keuangan_ts] = pd.to_datetime(df_transaksi_keuangan[nama_kolom_tanggal_keuangan_ts], errors='coerce')
            df_transaksi_keuangan.dropna(subset=[nama_kolom_tanggal_keuangan_ts], inplace=True)

            # Set kolom tanggal sebagai index untuk resampling
            df_transaksi_keuangan_ts = df_transaksi_keuangan.set_index(nama_kolom_tanggal_keuangan_ts)

            print(f"\nResampling Bulanan {nama_kolom_nilai_keuangan_ts} Transaksi Keuangan (Total Bulanan):")
            # Resampling bulanan, hitung total (sesuaikan 'sum()' jika perlu)
            resampled_data = df_transaksi_keuangan_ts[nama_kolom_nilai_keuangan_ts].resample('M').sum()
            # print(resampled_data.head()) # Opsional: tampilkan data yang di-resample

            # Visualisasi data yang di-resample - Berwarna
            plt.figure(figsize=(12, 7))
            resampled_data.plot(kind='line', marker='o', linestyle='-', color='teal') # Warna garis
            plt.title(f'Tren {nama_kolom_nilai_keuangan_ts} Transaksi Keuangan (Bulanan)', fontsize=14)
            plt.xlabel('Bulan', fontsize=12)
            plt.ylabel(f'Total {nama_kolom_nilai_keuangan_ts}', fontsize=12)
            plt.grid(True)
            plt.tight_layout()
            plt.show()

        else:
            print(f"Salah satu kolom ('{nama_kolom_tanggal_keuangan_ts}' atau '{nama_kolom_nilai_keuangan_ts}') tidak ditemukan untuk analisis deret waktu di df_transaksi_keuangan.")
    except Exception as e:
         print(f"Error saat analisis deret waktu df_transaksi_keuangan: {e}")


    print("\n" + "="*40)
    print("Visualisasi relasi dan tren selesai.")
    print("="*40)


else:
    print("\n--- Analisis Mendalam dan Visualisasi Dilewati Karena Gagal Memuat File ---")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: [Errno 2] No such file or directory: '/content/drive/My Drive/NamaFolderAnda/Tabel-Aset-Tetap.csv'. Pastikan file CSV berada di direktori yang sama atau tentukan path lengkapnya.
#
# --- Analisis Mendalam dan Visualisasi Dilewati Karena Gagal Memuat File ---

# %% [markdown]
# # Task
# buatkan grafik berwarna untuk memvisualisasikan hubungan antar kolom atau tren dalam data berdasarkan 3 tabel yang saya lampirkan
#
# Here is all the data you need:
# "tabel-aset-tetap.csv"
# "tabel-transaksi-keuangan.csv"
# "tabel kebijakan fiskal.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the three CSV files into pandas DataFrames.

# %% [markdown]
# **Reasoning**:
# Load the three CSV files into pandas DataFrames and display the first few rows to verify.  Try different encodings if necessary.

# %%
import pandas as pd

try:
    df_aset = pd.read_csv('tabel-aset-tetap.csv')
    display(df_aset.head())
except UnicodeDecodeError:
    try:
        df_aset = pd.read_csv('tabel-aset-tetap.csv', encoding='latin-1')
        display(df_aset.head())
    except UnicodeDecodeError:
        try:
            df_aset = pd.read_csv('tabel-aset-tetap.csv', encoding='cp1252')
            display(df_aset.head())
        except Exception as e:
            print(f"Error loading tabel-aset-tetap.csv: {e}")
            df_aset = None

try:
    df_transaksi = pd.read_csv('tabel-transaksi-keuangan.csv')
    display(df_transaksi.head())
except UnicodeDecodeError:
    try:
        df_transaksi = pd.read_csv('tabel-transaksi-keuangan.csv', encoding='latin-1')
        display(df_transaksi.head())
    except UnicodeDecodeError:
        try:
            df_transaksi = pd.read_csv('tabel-transaksi-keuangan.csv', encoding='cp1252')
            display(df_transaksi.head())
        except Exception as e:
            print(f"Error loading tabel-transaksi-keuangan.csv: {e}")
            df_transaksi = None

try:
    df_kebijakan = pd.read_csv('tabel kebijakan fiskal.csv')
    display(df_kebijakan.head())
except UnicodeDecodeError:
    try:
        df_kebijakan = pd.read_csv('tabel kebijakan fiskal.csv', encoding='latin-1')
        display(df_kebijakan.head())
    except UnicodeDecodeError:
        try:
            df_kebijakan = pd.read_csv('tabel kebijakan fiskal.csv', encoding='cp1252')
            display(df_kebijakan.head())
        except Exception as e:
            print(f"Error loading tabel kebijakan fiskal.csv: {e}")
            df_kebijakan = None
# Out:
#   aset_id   kategori nilai_perolehan  umur_ekonomis         metode
# 0    A001      Mesin       5,000,000             10    garis lurus
# 1    A002   Bangunan      25,000,000             20  saldo menurun
# 2    A003  Kendaraan       3,500,000              8    garis lurus
# 3    A004  Peralatan       2,000,000              5  saldo menurun
# 4    A005   Komputer       1,200,000              3    garis lurus
#    tahun  pendapatan beban_operasional penyusutan  skenario
# 0   2021  10,000,000         4,500,000  1,200,000  baseline
# 1   2022  12,500,000         5,200,000  1,400,000   optimis
# 2   2023  11,000,000         5,500,000  1,300,000   pesimis
# 3   2024  14,000,000         6,000,000  1,600,000   optimis
# 4   2025  15,500,000         6,800,000  1,800,000  baseline
#    tahun  tax_rate tax_holiday_awal tax_holiday_akhir
# 0   2021      0.25             2021              2022
# 1   2022      0.24                -                 -
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded datasets to understand their structure, identify relevant columns for visualization, and check for data quality issues.

# %% [markdown]
# **Reasoning**:
# I need to explore the data structure, calculate descriptive statistics, check for missing values, and examine potential relationships between the datasets.

# %%
# Examine Data Structure and Types
print("DataFrame: df_aset")
print(df_aset.info())
print("\nDataFrame: df_transaksi")
print(df_transaksi.info())
print("\nDataFrame: df_kebijakan")
print(df_kebijakan.info())

# Descriptive Statistics
print("\nDescriptive Statistics for Numerical Columns:")
print("\nDataFrame: df_aset")
print(df_aset.describe(include='number'))
print("\nDataFrame: df_transaksi")
print(df_transaksi.describe(include='number'))
# 'tax_rate' is the only numerical column in df_kebijakan
print("\nDataFrame: df_kebijakan")
print(df_kebijakan.describe(include='number'))


# Missing Values
print("\nMissing Values:")
print("\nDataFrame: df_aset")
print(df_aset.isnull().sum())
print(df_aset.isnull().sum() / len(df_aset) * 100)
print("\nDataFrame: df_transaksi")
print(df_transaksi.isnull().sum())
print(df_transaksi.isnull().sum() / len(df_transaksi) * 100)
print("\nDataFrame: df_kebijakan")
print(df_kebijakan.isnull().sum())
print(df_kebijakan.isnull().sum() / len(df_kebijakan) * 100)

# Data Relationships (focus on 'tahun' and potential merges)
print("\nData Relationships (Year and Potential Merges):")
print("\nUnique years in df_transaksi:", df_transaksi['tahun'].unique())
print("Unique years in df_kebijakan:", df_kebijakan['tahun'].unique())
# Check for common years
common_years = set(df_transaksi['tahun']).intersection(set(df_kebijakan['tahun']))
print("Common years between df_transaksi and df_kebijakan:", common_years)
# Out:
# DataFrame: df_aset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   aset_id          5 non-null      object
#  1   kategori         5 non-null      object
#  2   nilai_perolehan  5 non-null      object
#  3   umur_ekonomis    5 non-null      int64
#  4   metode           5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 332.0+ bytes
# None
#
# DataFrame: df_transaksi
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tahun              5 non-null      int64
#  1   pendapatan         5 non-null      object
#  2   beban_operasional  5 non-null      object
#  3   penyusutan         5 non-null      object
#  4   skenario           5 non-null      object
# ...

# %% [markdown]
# ## Data preparation
#
# ### Subtask:
# Data Cleaning and Preparation for Visualization

# %% [markdown]
# **Reasoning**:
# Convert relevant columns to numeric types, merge the dataframes, and perform feature engineering.

# %%
import pandas as pd
import numpy as np

# Data Type Conversion
for col in ['nilai_perolehan', 'pendapatan', 'beban_operasional', 'penyusutan']:
    if col in df_aset.columns:
        df_aset[col] = pd.to_numeric(df_aset[col].astype(str).str.replace(r'[.,]', '', regex=True), errors='coerce')
    if col in df_transaksi.columns:
        df_transaksi[col] = pd.to_numeric(df_transaksi[col].astype(str).str.replace(r'[.,]', '', regex=True), errors='coerce')

# Merge DataFrames
# Using an inner merge on 'tahun' as both dataframes have the same years.
df_merged = pd.merge(df_transaksi, df_kebijakan, on='tahun', how='inner')

# Feature Engineering
# Calculate operating expense ratio
df_merged['operasional_ratio'] = df_merged['beban_operasional'] / df_merged['pendapatan']

# Calculate year-over-year revenue growth
df_merged['pendapatan_growth'] = df_merged['pendapatan'].pct_change() * 100

# Calculate depreciation as a percentage of acquisition value
# Assuming nilai_perolehan is constant over the years.
# Note: The current dataset structure doesn't allow for a meaningful calculation of depreciation as a percentage of acquisition value without more data.
# We'll fill in a placeholder for now; a more comprehensive method would be needed given more data.
df_merged['penyusutan_percentage'] = df_merged['penyusutan'] / df_merged['pendapatan']*100


# Handle Missing Values (if any)
# Check for any missing values after merging
print(df_merged.isnull().sum())

# If there are missing values, consider imputation or removal.
# In this case, there are no missing values, so no action is needed.
# Example of imputation (if needed):
# df_merged['pendapatan_growth'].fillna(0, inplace=True)

display(df_merged)
# Out:
# tahun                    0
# pendapatan               0
# beban_operasional        0
# penyusutan               0
# skenario                 0
# tax_rate                 0
# tax_holiday_awal         0
# tax_holiday_akhir        0
# operasional_ratio        0
# pendapatan_growth        1
# penyusutan_percentage    0
# dtype: int64
#    tahun  pendapatan  beban_operasional  penyusutan  skenario  tax_rate  \
# 0   2021    10000000            4500000     1200000  baseline      0.25
# 1   2022    12500000            5200000     1400000   optimis      0.24
# 2   2023    11000000            5500000     1300000   pesimis      0.23
# 3   2024    14000000            6000000     1600000   optimis      0.22
# 4   2025    15500000            6800000     1800000  baseline      0.21
#
#   tax_holiday_awal tax_holiday_akhir  operasional_ratio  pendapatan_growth  \
# 0             2021              2022           0.450000                NaN
# ...

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize relationships and trends in the merged dataset.

# %% [markdown]
# **Reasoning**:
# Create the visualizations as specified in the instructions, handling potential errors gracefully.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot of pendapatan vs. beban_operasional, colored by tax_rate
plt.figure(figsize=(8, 6))
sns.scatterplot(x='pendapatan', y='beban_operasional', hue='tax_rate', data=df_merged, palette='viridis')
plt.title('Pendapatan vs. Beban Operasional (Colored by Tax Rate)')
plt.xlabel('Pendapatan')
plt.ylabel('Beban Operasional')
plt.show()


# Line plot showing trends of pendapatan and beban_operasional over tahun
plt.figure(figsize=(10, 6))
sns.lineplot(x='tahun', y='pendapatan', data=df_merged, label='Pendapatan', marker='o', color='blue')
sns.lineplot(x='tahun', y='beban_operasional', data=df_merged, label='Beban Operasional', marker='s', color='red')
plt.title('Tren Pendapatan dan Beban Operasional')
plt.xlabel('Tahun')
plt.ylabel('Nilai (Rupiah)')
plt.legend()
plt.show()


# Bar plot comparing pendapatan across different skenario
plt.figure(figsize=(8, 6))
sns.barplot(x='skenario', y='pendapatan', data=df_merged, palette='pastel')
plt.title('Perbandingan Pendapatan antar Skenario')
plt.xlabel('Skenario')
plt.ylabel('Pendapatan')
plt.show()
# Out:
# <ipython-input-4-8db442fbffb3>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='skenario', y='pendapatan', data=df_merged, palette='pastel')

# %% [markdown]
# **Reasoning**:
# The previous code block generated the plots, but there was a warning about the `palette` argument in `sns.barplot`. I will fix this by assigning the `x` variable to `hue` and set `legend=False`. Also, I will add more detailed labels and legend titles.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot of pendapatan vs. beban_operasional, colored by tax_rate
plt.figure(figsize=(8, 6))
sns.scatterplot(x='pendapatan', y='beban_operasional', hue='tax_rate', data=df_merged, palette='viridis')
plt.title('Pendapatan vs. Beban Operasional (Colored by Tax Rate)')
plt.xlabel('Pendapatan (IDR)')
plt.ylabel('Beban Operasional (IDR)')
plt.legend(title='Tax Rate')
plt.show()


# Line plot showing trends of pendapatan and beban_operasional over tahun
plt.figure(figsize=(10, 6))
sns.lineplot(x='tahun', y='pendapatan', data=df_merged, label='Pendapatan', marker='o', color='blue')
sns.lineplot(x='tahun', y='beban_operasional', data=df_merged, label='Beban Operasional', marker='s', color='red')
plt.title('Tren Pendapatan dan Beban Operasional dari Tahun ke Tahun')
plt.xlabel('Tahun')
plt.ylabel('Nilai (IDR)')
plt.legend(title='Keterangan')
plt.show()


# Bar plot comparing pendapatan across different skenario
plt.figure(figsize=(8, 6))
sns.barplot(x='skenario', y='pendapatan', hue='skenario', data=df_merged, palette='pastel', legend=False)
plt.title('Perbandingan Pendapatan antar Skenario')
plt.xlabel('Skenario')
plt.ylabel('Pendapatan (IDR)')
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Q&A
# No questions detected in the provided text.
#
# ### Data Analysis Key Findings
# *   Three CSV files (tabel-aset-tetap.csv, tabel-transaksi-keuangan.csv, and tabel kebijakan fiskal.csv) were loaded into pandas DataFrames.
# *   Several columns representing numerical data were initially of object type and required conversion to numeric types.  Non-numeric characters were removed during conversion.
# *   The `df_transaksi` and `df_kebijakan` DataFrames were merged using an inner join on the 'tahun' column.
# *   New features were engineered, including the operating expense ratio, year-over-year revenue growth, and depreciation as a percentage of revenue.
# *   Three visualizations were generated:
#     *   A scatter plot of revenue vs. operating expenses, colored by tax rate.
#     *   A line plot showing trends of revenue and operating expenses over time.
#     *   A bar plot comparing revenue across different scenarios.
#
# ### Insights or Next Steps
# *   Explore the relationship between the newly engineered features (operating expense ratio, revenue growth) and the tax rate.
# *   Investigate the potential impact of different fiscal policy scenarios on revenue and profitability using more sophisticated statistical models or forecasting techniques.
